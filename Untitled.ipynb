# %%
import os              # accessing directory structure
import numpy as np     # linear algebra
import pandas as pd    
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import scipy
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
# libraries for maps
from mpl_toolkits.basemap import Basemap as Basemap
from matplotlib.colors import rgb2hex
from matplotlib.patches import Polygon

# %matplotlib inline
# pyplt.style.use('seaborn-whitegrid')
# sns.set_context("poster")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/1354930023.py in <module>
#       9 from sklearn.preprocessing import StandardScaler
#      10 # libraries for maps
# ---> 11 from mpl_toolkits.basemap import Basemap as Basemap
#      12 from matplotlib.colors import rgb2hex
#      13 from matplotlib.patches import Polygon
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
import os              
import numpy as np 
import pandas as pd    
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import scipy
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

# %%
# libraries for maps
from mpl_toolkits.basemap import Basemap as Basemap
from matplotlib.colors import rgb2hex
from matplotlib.patches import Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3766490107.py in <module>
#       1 # libraries for maps
# ----> 2 from mpl_toolkits.basemap import Basemap as Basemap
#       3 from matplotlib.colors import rgb2hex
#       4 from matplotlib.patches import Polygon
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
python -m pip install basemap-data
python -m pip install basemap-data-hires
# Out:
#   File "C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3675770191.py", line 1
#     python -m pip install basemap-data
#               ^
# SyntaxError: invalid syntax

# %%
# libraries for maps
from mpl_toolkits.basemap import Basemap as Basemap
from matplotlib.colors import rgb2hex
from matplotlib.patches import Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3924203852.py in <module>
#       1 # libraries for maps
# ----> 2 from mpl_toolkits.basemap import Basemap as Basemap
#       3 from matplotlib.colors import rgb2hex
#       4 from matplotlib.patches import Polygon
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
from matplotlib.colors import rgb2hex

# %%
from matplotlib.patches import Polygon

# %%
solar=pd.read_csv('ALY 6000.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/842159426.py in <module>
# ----> 1 solar=pd.read_csv('ALY 6000.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
solar=pd.read_csv('ALY 6000 Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/2623806487.py in <module>
# ----> 1 solar=pd.read_csv('ALY 6000 Dataset.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df=pd.read_xlsx('https://northeastern-my.sharepoint.com/personal/mallavarapu_r_northeastern_edu/Documents/Desktop/ALY%206000%20Dataset.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/1575648821.py in <module>
# ----> 1 df=pd.read_xlsx('https://northeastern-my.sharepoint.com/personal/mallavarapu_r_northeastern_edu/Documents/Desktop/ALY%206000%20Dataset.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
solardata.fillna(solardata.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3977508786.py in <module>
# ----> 1 solardata.fillna(solardata.mean())
#
# NameError: name 'solardata' is not defined

# %%
import os              # accessing directory structure
import numpy as np     # linear algebra
import pandas as pd    
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import scipy
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
# libraries for maps
from mpl_toolkits.basemap import Basemap as Basemap
from matplotlib.colors import rgb2hex
from matplotlib.patches import Polygon

# %matplotlib inline
# pyplt.style.use('seaborn-whitegrid')
# sns.set_context("poster")
print("Libraries imported.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/1354930023.py in <module>
#       9 from sklearn.preprocessing import StandardScaler
#      10 # libraries for maps
# ---> 11 from mpl_toolkits.basemap import Basemap as Basemap
#      12 from matplotlib.colors import rgb2hex
#      13 from matplotlib.patches import Polygon
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
import pandas as pd

# %%
df = pd.read_csv('ALY6000Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3350422145.py in <module>
# ----> 1 df = pd.read_csv('ALY6000Dataset.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
solar = pd.read_csv("C:/Users/Niteesh Mallavarapu/OneDrive - Northeastern University/Desktop")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/787335356.py in <module>
# ----> 1 solar = pd.read_csv("C:/Users/Niteesh Mallavarapu/OneDrive - Northeastern University/Desktop")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
solar = pd.read_csv("C:/Analytics.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/4169495931.py in <module>
# ----> 1 solar = pd.read_csv("C:/Analytics.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
solar = pd.read_csv("C:/Analytics.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/4169495931.py in <module>
# ----> 1 solar = pd.read_csv("C:/Analytics.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv('ALY6000Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3350422145.py in <module>
# ----> 1 df = pd.read_csv('ALY6000Dataset.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_excel('C:/Users/Niteesh Mallavarapu/OneDrive - Northeastern University/Desktop.xlsx', 'Sheet1')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/4131630132.py in <module>
# ----> 1 df = pd.read_excel('C:/Users/Niteesh Mallavarapu/OneDrive - Northeastern University/Desktop.xlsx', 'Sheet1')
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
df = pd.read_excel('ALY6000Dataset.xlsx', 'Sheet1')
df
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#              fips  average_household_income              county  \
# 0     27145011200              70352.789869      Stearns County
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  tile_count  solar_system_count  total_panel_area         fips  \
# 0           0           0                   0          0.000000  27145011200
# 1           1          25                  21       1133.436461  27145011301
# 2           2           3                   3         64.505776  27145011302
# 3           3           0                   0          0.000000  27145011304
# 4           4           5                   5        164.583303  27145011400
#
#    average_household_income          county  education_bachelor  \
# 0              70352.789869  Stearns County                 569
# 1              61727.085202  Stearns County                 674
# 2              71496.886583  Stearns County                 854
# 3              86840.152755  Stearns County                 640
# 4              89135.315597  Stearns County                 654
#
#    education_college  education_doctoral  ...  incentive_count_nonresidential  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Columns: 169 entries, Unnamed: 0 to avg_electricity_retail_rate
# dtypes: bool(2), float64(112), int64(53), object(2)
# memory usage: 1.5+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tile_count', 'solar_system_count', 'total_panel_area',
#        'fips', 'average_household_income', 'county', 'education_bachelor',
#        'education_college', 'education_doctoral',
#        ...
#        'incentive_count_nonresidential', 'incentive_residential_state_level',
#        'incentive_nonresidential_state_level', 'net_metering', 'feedin_tariff',
#        'cooperate_tax', 'property_tax', 'sales_tax', 'rebate',
#        'avg_electricity_retail_rate'],
#       dtype='object', length=169)

# %%
df.describe()
# Out:
#         Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# count  1199.000000  1199.00000         1199.000000       1199.000000
# mean    599.000000    49.92744           34.729775       2122.159651
# std     346.265794    76.20852           44.776653       7854.080042
# min       0.000000     0.00000            0.000000          0.000000
# 25%     299.500000    11.00000            8.000000        282.016442
# 50%     599.000000    25.00000           18.000000        707.329347
# 75%     898.500000    62.00000           44.000000       1933.160204
# max    1198.000000  1463.00000          324.000000     216732.195619
#
#                fips  average_household_income  education_bachelor  \
# count  1.199000e+03               1169.000000         1199.000000
# mean   8.526792e+09              77153.723010          567.783153
# std    8.004043e+09              42461.695396          449.742896
# min    6.037101e+09               9040.000000            0.000000
# ...

# %%
df.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3499318098.py in <module>
# ----> 1 df.hist()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     224     """
#     225     plot_backend = _get_plot_backend(backend)
# --> 226     return plot_backend.hist_frame(
#     227         data,
#     228         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     462         if legend and can_set_label:
#     463             kwds["label"] = col
# ...

# %%
x=df.drop(columns=['fips','education_bachelor','education_college','education_doctoral','education_high_school_graduate','education_less_than_high_school','education_master','education_population','education_professional_school','employed'])

# %%
x=df.drop(columns=['poverty_family_below_poverty_level','race_asian','race_black_africa','race_indian_alaska','race_islander','race_other','race_two_more','race_white','race_white_rate','race_black_africa_rate','race_indian_alaska_rate','race_asian_rate','race_other_rate'])

# %%
x
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#              fips  average_household_income              county  \
# 0     27145011200              70352.789869      Stearns County
# ...

# %%
x.fillna(x.mean())
# Out:
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/2029865756.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x.fillna(x.mean())
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# ...

# %%
x.head()
# Out:
#    Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0           0           0                   0          0.000000
# 1           1          25                  21       1133.436461
# 2           2           3                   3         64.505776
# 3           3           0                   0          0.000000
# 4           4           5                   5        164.583303
#
#    average_household_income          county  gini_index  \
# 0              70352.789869  Stearns County      0.3490
# 1              61727.085202  Stearns County      0.4074
# 2              71496.886583  Stearns County      0.3926
# 3              86840.152755  Stearns County      0.3949
# 4              89135.315597  Stearns County      0.4463
#
#    heating_fuel_coal_coke  heating_fuel_electricity  \
# 0                     200                       448
# 1                      20                       379
# 2                      69                       440
# ...

# %%
# Out:
# Histogram:Solar Panel Counts
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/3947461804.py in <module>
#       1 print("Histogram:Solar Panel Counts")
#       2 fig, ax = plt.subplots(figsize=(20, 7))
# ----> 3 tile_count = solardata['tile_count']
#       4 plt.hist(tile_count, 35, range=[0, 400], facecolor='goldenrod', align='mid')
#       5 plt.show()
#
# NameError: name 'solardata' is not defined

# %%
print("Histogram : Solar Panel Counts")
fig, ax = plt.subplots(figsize=(20, 7))
tile_count = x['tile_count']
plt.hist(tile_count, 35, range=[0, 400], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Histogram : Solar Panel Counts

# %%
print("Histogram : Solar Panel Counts(Limits: 20 to 200)")
tile_count = x['tile_count']
fig, ax = plt.subplots(figsize=(20, 7))
plt.hist(tile_count, 30, range=[20, 200], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Histogram : Solar Panel Counts(Limits: 20 to 200)

# %%
print("Histogram : Solar Panel Area per Capita")
area_capita = x['solar_panel_area_per_capita']
fig, ax = plt.subplots(figsize=(20, 5))
plt.hist(area_capita, 40, range=[0, 1.5], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Histogram : Solar Panel Area per Capita

# %%
print("Histogram : Solar Panel Area per Capita")
area_capita = x['solar_panel_area_per_capita']
fig, ax = plt.subplots(figsize=(20, 5))
plt.hist(area_capita, 40, range=[0, 1.0], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Histogram : Solar Panel Area per Capita

# %%
print("Histogram : Solar Panel Area per Capita")
area_capita = x['solar_panel_area_per_capita']
fig, ax = plt.subplots(figsize=(20, 5))
plt.hist(area_capita, 40, range=[0, 1], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Histogram : Solar Panel Area per Capita

# %%
print("Histogram : Solar Panel Area per Capita ( Limiting Range)")
area_capita = x['solar_panel_area_per_capita']
fig, ax = plt.subplots(figsize=(20, 8))
plt.hist(area_capita, 35, range=[0.1, 0.6], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Histogram : Solar Panel Area per Capita ( Limiting Range)

# %%
print("BarPlot Analysis")
print()


total_tile = int(x['tile_count'].sum())
print("Total Number of Solar Panels:", total_tile)
total_system = int(x['solar_system_count'].sum())
print("Total Number of Solar Panel Systems:", total_system)

avg_tile_count = total_tile/72495
avg_tile_per_system = total_tile/ total_system
print("Average Number of Solar Panels:", round(avg_tile_count))
print("Average Number of Panels per Solar Panel System:", avg_tile_per_system)

print()
total_rtile = int(x['tile_count_residential'].sum())
print("Total Number of Solar Panels for Residential Purposes:", total_rtile)
total_nrtile = int(x['tile_count_nonresidential'].sum())
print("Total Number of Solar Panels for Non-Residential Purposes*:", total_nrtile)
print()
total_rsystem = int(x['solar_system_count_residential'].sum())
print("Total Number of Solar Systems for Residential Purposes:", total_rsystem)
total_nrsystem = int(x['solar_system_count_nonresidential'].sum())
print("Total Number of Solar Panels for Non-Residential Purposes*:", total_nrsystem)
print()


barWidth = 0.2
 
barstotal = [total_tile, total_system]
barsres = [total_rtile, total_rsystem]
barsnonres = [total_nrtile, total_nrsystem]
 

r1 = np.arange(len(barstotal))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

fig, ax = plt.subplots(figsize=(15, 8))
 

plt.bar(r1, barstotal, color='goldenrod', width=barWidth, edgecolor='white', label='total')
plt.bar(r2, barsres, color='cadetblue', width=barWidth, edgecolor='white', label='residential')
plt.bar(r3, barsnonres, color='darkseagreen', width=barWidth, edgecolor='white', label='nonresidential')
 

plt.xlabel('Residential and Non-Residential Use of Solar Energy', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(barstotal))], ["Solar Panels", "Solar Systems"])
 

plt.legend()
plt.show()
# Out:
# BarPlot Analysis
#
# Total Number of Solar Panels: 59863
# Total Number of Solar Panel Systems: 41641
# Average Number of Solar Panels: 1
# Average Number of Panels per Solar Panel System: 1.4375975600970197
#
# Total Number of Solar Panels for Residential Purposes: 44654
# Total Number of Solar Panels for Non-Residential Purposes*: 15209
#
# Total Number of Solar Systems for Residential Purposes: 37370
# Total Number of Solar Panels for Non-Residential Purposes*: 4271

# %%
#define columns to find correlations  
energyenv_quant_data = ["total_panel_area", "total_panel_area_residential", "total_panel_area_nonresidential","electricity_price_overall", "avg_electricity_retail_rate", "electricity_consume_total", "incentive_count_residential", "incentive_count_nonresidential", "heating_fuel_gas_rate", "heating_fuel_solar_rate","daily_solar_radiation",  "air_temperature",]

fig, axe = plt.subplots(figsize=(14,14))
sns.set_context("poster")
# RdYlBu_r
sns.set(font_scale=1.3)
corrmap = sns.color_palette("BrBG", 100)
sns.heatmap(x[energyenv_quant_data].corr(),annot=True, fmt='.2f',linewidths=1,cmap = corrmap)
# Out:
# <AxesSubplot:>

# %%
energyenv_quant_data = ["total_panel_area", "total_panel_area_residential", "total_panel_area_nonresidential","electricity_price_overall", "avg_electricity_retail_rate", "electricity_consume_total", "incentive_count_residential", "incentive_count_nonresidential", "heating_fuel_gas_rate", "heating_fuel_solar_rate","daily_solar_radiation",  "air_temperature",]

fig, axe = plt.subplots(figsize=(14,14))
sns.set_context("poster")

sns.set(font_scale=1.4)
corrmap = sns.color_palette("RdGy", 100)
sns.heatmap(x[energyenv_quant_data].corr(),annot=True, fmt='.2f',linewidths=1,cmap = corrmap)
# Out:
# <AxesSubplot:>

# %%
fig, axe = plt.subplots(figsize=(10,10))
sns.regplot(x=x["incentive_count_residential"], y=x["total_panel_area_residential"], fit_reg=True)
# Out:
# <AxesSubplot:xlabel='incentive_count_residential', ylabel='total_panel_area_residential'>

# %%
socioecon_quant_data = ["total_panel_area", "total_panel_area_residential", "median_household_income","number_of_years_of_education", "age_median", "poverty_family_count", "per_capita_income", "population_density", "employ_rate", "gini_index", "diversity", "voting_2016_dem_percentage", 'voting_2016_gop_percentage']

fig, axe = plt.subplots(figsize=(16,16))
sns.set_context("poster")

sns.set(font_scale=1.3)
colmap2 = sns.color_palette("coolwarm", 100)
sns.heatmap(x[socioecon_quant_data].corr(),annot=True, fmt='.2f',linewidths=1,cmap = colmap2)
# Out:
# <AxesSubplot:>

# %%
print("Linear Regression Plot of Median Household Income and Total Residential Panel Area")
fig, axe = plt.subplots(figsize=(10,10))
sns.regplot(x=x["median_household_income"], y=x["total_panel_area_residential"], fit_reg=True)
# Out:
# Linear Regression Plot of Median Household Income and Total Residential Panel Area
# <AxesSubplot:xlabel='median_household_income', ylabel='total_panel_area_residential'>

# %%
#Creating the dataset
df = sns.load_dataset('ALY6000Dataset.xlsx') 
df=df.groupby('who')['fare'].sum().to_frame().reset_index()

#Creating the bar chart 
plt.barh(df['who'],df['fare'],color = ['#F0F8FF','#E6E6FA','#B0E0E6']) 

#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title') 

#Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/20411172.py in <module>
#       1 #Creating the dataset
# ----> 2 df = sns.load_dataset('ALY6000Dataset.xlsx')
#       3 df=df.groupby('who')['fare'].sum().to_frame().reset_index()
#       4
#       5 #Creating the bar chart
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'ALY6000Dataset.xlsx' is not one of the example datasets.

# %%
print("Comparison between three countries")
area_capita = x['county']
fig, ax = plt.subplots(figsize=(20, 8))
plt.hist(area_capita, 35, range=[0, 50], facecolor='rosybrown', align='mid')
plt.show()
# Out:
# Comparison between three countries

# %%
x.plot()
# Out:
# county
# Los Angeles County    AxesSubplot(0.125,0.125;0.775x0.755)
# Orange County         AxesSubplot(0.125,0.125;0.775x0.755)
# Stearns County        AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.groupby([df.index.date, 'county']).count().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/2497729001.py in <module>
# ----> 1 df.groupby([df.index.date, 'county']).count().plot(kind='bar')
#
# AttributeError: 'RangeIndex' object has no attribute 'date'

# %%
x.groupby([df.index.date, 'county']).count().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/2763568529.py in <module>
# ----> 1 x.groupby([df.index.date, 'county']).count().plot(kind='bar')
#
# AttributeError: 'RangeIndex' object has no attribute 'date'

# %%
df1.groupby('county').size().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/2144572197.py in <module>
# ----> 1 df1.groupby('county').size().plot.bar()
#
# NameError: name 'df1' is not defined

# %%
x.groupby('county').size().plot.bar()
# Out:
# <AxesSubplot:xlabel='county'>

# %%
print("Median vs County")
fig, axe = plt.subplots(figsize=(10,10))
sns.regplot(x=x["median_household_income"], y=x["county"], fit_reg=True)
# Out:
# Median vs County
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/1160932807.py in <module>
#       1 print("Median vs County")
#       2 fig, axe = plt.subplots(figsize=(10,10))
# ----> 3 sns.regplot(x=x["median_household_income"], y=x["county"], fit_reg=True)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
# ...

# %%
print("Median vs County")
fig, axe = plt.subplots(figsize=(10,10))
sns.regplot(x=x["median_household_income"], y=x["county"], fit_reg=True)
# Out:
# Median vs County
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/1160932807.py in <module>
#       1 print("Median vs County")
#       2 fig, axe = plt.subplots(figsize=(10,10))
# ----> 3 sns.regplot(x=x["median_household_income"], y=x["county"], fit_reg=True)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
# ...

# %%
df = pd.read_excel('ALY6000Dataset.xlsx', 'Sheet1')
df
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#              fips  average_household_income              county  \
# 0     27145011200              70352.789869      Stearns County
# ...

# %%
print("Median vs County")
fig, axe = plt.subplots(figsize=(10,10))
sns.regplot(x=x["median_household_income"], y=x["county"], fit_reg=True)
# Out:
# Median vs County
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/1160932807.py in <module>
#       1 print("Median vs County")
#       2 fig, axe = plt.subplots(figsize=(10,10))
# ----> 3 sns.regplot(x=x["median_household_income"], y=x["county"], fit_reg=True)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#             fips  average_household_income              county  \
# 1194  6037104403              53996.677215  Los Angeles County
# 1195  6037104500              56626.666667  Los Angeles County
# 1196  6037302401              48904.564706  Los Angeles County
# 1197  6037104610              50372.510519  Los Angeles County
# 1198  6037104620              56400.277392  Los Angeles County
#
#       education_bachelor  education_college  education_doctoral  ...  \
# 1194                 201                241                   0  ...
# ...

# %%
df = pd.read_excel('ALY6000Dataset.xlsx', 'Sheet1')
df
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#              fips  average_household_income              county  \
# 0     27145011200              70352.789869      Stearns County
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#             fips  average_household_income              county  \
# 1194  6037104403              53996.677215  Los Angeles County
# 1195  6037104500              56626.666667  Los Angeles County
# 1196  6037302401              48904.564706  Los Angeles County
# 1197  6037104610              50372.510519  Los Angeles County
# 1198  6037104620              56400.277392  Los Angeles County
#
#       education_bachelor  education_college  education_doctoral  ...  \
# 1194                 201                241                   0  ...
# ...

# %%
print("Electricity vs County")
fig, axe = plt.subplots(figsize=(10,10))
sns.regplot(x=x["electricity_price_residential"], y=x["county"], fit_reg=True)
# Out:
# Electricity vs County
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/207917575.py in <module>
#       1 print("Electricity vs County")
#       2 fig, axe = plt.subplots(figsize=(10,10))
# ----> 3 sns.regplot(x=x["electricity_price_residential"], y=x["county"], fit_reg=True)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#             fips  average_household_income              county  \
# 1194  6037104403              53996.677215  Los Angeles County
# 1195  6037104500              56626.666667  Los Angeles County
# 1196  6037302401              48904.564706  Los Angeles County
# 1197  6037104610              50372.510519  Los Angeles County
# 1198  6037104620              56400.277392  Los Angeles County
#
#       education_bachelor  education_college  education_doctoral  ...  \
# 1194                 201                241                   0  ...
# ...

# %%
df = pd.read_excel('ALY6000Dataset.xlsx', 'Sheet1')
df
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#              fips  average_household_income              county  \
# 0     27145011200              70352.789869      Stearns County
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#             fips  average_household_income              county  \
# 1194  6037104403              53996.677215  Los Angeles County
# 1195  6037104500              56626.666667  Los Angeles County
# 1196  6037302401              48904.564706  Los Angeles County
# 1197  6037104610              50372.510519  Los Angeles County
# 1198  6037104620              56400.277392  Los Angeles County
#
#       education_bachelor  education_college  education_doctoral  ...  \
# 1194                 201                241                   0  ...
# ...

# %%
x
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 0              0           0                   0          0.000000
# 1              1          25                  21       1133.436461
# 2              2           3                   3         64.505776
# 3              3           0                   0          0.000000
# 4              4           5                   5        164.583303
# ...          ...         ...                 ...               ...
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#              fips  average_household_income              county  \
# 0     27145011200              70352.789869      Stearns County
# ...

# %%
x.tail()
# Out:
#       Unnamed: 0  tile_count  solar_system_count  total_panel_area  \
# 1194        1194          25                  22        604.961766
# 1195        1195          35                  30        678.720556
# 1196        1196          52                  21       5369.330168
# 1197        1197          42                  37        948.992239
# 1198        1198          32                  26        651.128609
#
#             fips  average_household_income              county  \
# 1194  6037104403              53996.677215  Los Angeles County
# 1195  6037104500              56626.666667  Los Angeles County
# 1196  6037302401              48904.564706  Los Angeles County
# 1197  6037104610              50372.510519  Los Angeles County
# 1198  6037104620              56400.277392  Los Angeles County
#
#       education_bachelor  education_college  education_doctoral  ...  \
# 1194                 201                241                   0  ...
# ...

# %%
county.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\NITEES~1\AppData\Local\Temp/ipykernel_28448/257656162.py in <module>
# ----> 1 county.mean()
#
# NameError: name 'county' is not defined
